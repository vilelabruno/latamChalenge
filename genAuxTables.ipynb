# %%
import pandas as pd
cat62 = pd.read_csv('data/cat62.csv')

# %%
bimtra = pd.read_csv('data/bimtra.csv')

# %%
bimtra["linha"] = bimtra["origem"] + bimtra["destino"]

# %%
bimtra = bimtra.groupby("flightid")["linha"].first()

# %%
bimtra = pd.DataFrame(bimtra).reset_index()

# %%
bimtra
# Out:
#                                 flightid     linha
# 0       0000f76a51b99be3f181ea2b201b34ef  SBSVSBGR
# 1       00010bb2c49076d56a9815122fefc8aa  SBCFSBSP
# 2       00010ed6d09c78b5a37f4df13f524f56  SBSVSBSP
# 3       000143522a56fa245543e477c74fd908  SBSPSBRF
# 4       00014fa436546dfdc7a67919e9e1ea47  SBCFSBFL
# ...                                  ...       ...
# 262411  fffea9a5cfeeb8f24e738cf60a1d5f2b  SBGRSBPA
# 262412  fffeba6342187a9ee0caff2526e4ff0e  SBSPSBPA
# 262413  ffff413d10cfbb298a9411855e80a0f0  SBRJSBPA
# 262414  ffffd0e5ce497de7ddf3d34d19b9ce3a  SBSPSBRJ
# 262415  ffffd4331f8b78c6e726eda4e6a2f5ac  SBGRSBRF
#
# [262416 rows x 2 columns]

# %%
cat62 = cat62.merge(bimtra, on="flightid", how="left")

# %%
cat62
# Out:
#                                   flightid        lat        lon  flightlevel  \
# 0         62e589aaa96762725b092b898d48a35e -25.044874 -48.453541        210.0
# 1         62e589aaa96762725b092b898d48a35e -23.513367 -47.060570        105.0
# 2         62e589aaa96762725b092b898d48a35e -23.515486 -47.065519        106.0
# 3         62e589aaa96762725b092b898d48a35e -29.233669 -50.641993        177.0
# 4         62e589aaa96762725b092b898d48a35e -28.122698 -50.041957        210.0
# ...                                    ...        ...        ...          ...
# 37122487  0330f20d67f552088ed730f06f0c8e1b -29.440907 -50.955963        245.0
# 37122488  0330f20d67f552088ed730f06f0c8e1b -29.524358 -51.206169        197.0
# 37122489  0330f20d67f552088ed730f06f0c8e1b -23.524014 -46.725162         46.0
# 37122490  0330f20d67f552088ed730f06f0c8e1b -26.768997 -48.395374        350.0
# 37122491  0330f20d67f552088ed730f06f0c8e1b -28.066242 -49.496078        350.0
#
#           speed      dt_radar     linha
# 0         266.0  1.654056e+12  SBPASBGR
# 1         266.0  1.654057e+12  SBPASBGR
# 2         266.0  1.654057e+12  SBPASBGR
# 3         221.0  1.654052e+12  SBPASBGR
# 4         270.0  1.654053e+12  SBPASBGR
# ...         ...           ...       ...
# 37122487  434.0  1.684007e+12       NaN
# 37122488  406.0  1.684007e+12       NaN
# 37122489  162.0  1.684011e+12       NaN
# 37122490  446.0  1.684009e+12       NaN
# 37122491  457.0  1.684008e+12       NaN
#
# [37122492 rows x 7 columns]

# %%
import numpy as np
# Convert dt_radar to datetime
cat62['dt_radar'] = pd.to_datetime(cat62['dt_radar'], unit='ms')

# Calculate flight time for each flightid
cat62['flight_time'] = cat62.groupby('flightid')['dt_radar'].transform(lambda x: x.max() - x.min())

# Convert flight time to seconds for easier calculation
cat62['flight_time'] = cat62['flight_time'].dt.total_seconds()

# Get mean and std for each linha
grouped = cat62.groupby('linha')['flight_time'].agg(['mean', 'std'])

# Merge the stats back into the original dataframe
df = cat62.merge(grouped, left_on = 'linha', right_index = True)

# Calculate the z-score for each flightid in each linha
df['z_score'] = np.abs((df['flight_time'] - df['mean']) / df['std'])

# %%
df.dropna(inplace=True)
df
# Out:
#                                   flightid        lat        lon  flightlevel  \
# 0         62e589aaa96762725b092b898d48a35e -25.044874 -48.453541        210.0
# 1         62e589aaa96762725b092b898d48a35e -23.513367 -47.060570        105.0
# 2         62e589aaa96762725b092b898d48a35e -23.515486 -47.065519        106.0
# 3         62e589aaa96762725b092b898d48a35e -29.233669 -50.641993        177.0
# 4         62e589aaa96762725b092b898d48a35e -28.122698 -50.041957        210.0
# ...                                    ...        ...        ...          ...
# 24940214  c732895ccea21c58612c5842ee19d0ae -24.223112 -44.281000        380.0
# 24940215  c732895ccea21c58612c5842ee19d0ae -23.430284 -43.477508        380.0
# 24940216  c732895ccea21c58612c5842ee19d0ae -17.714326 -39.803552        380.0
# 24940217  c732895ccea21c58612c5842ee19d0ae -17.394455 -39.620847        380.0
# 24940218  c732895ccea21c58612c5842ee19d0ae -23.423617 -43.471897        380.0
#
#           speed            dt_radar     linha  flight_time          mean  \
# 0         266.0 2022-06-01 03:54:06  SBPASBGR       7204.0   5156.463873
# 1         266.0 2022-06-01 04:21:04  SBPASBGR       7204.0   5156.463873
# 2         266.0 2022-06-01 04:21:01  SBPASBGR       7204.0   5156.463873
# 3         221.0 2022-06-01 02:50:00  SBPASBGR       7204.0   5156.463873
# 4         270.0 2022-06-01 03:08:02  SBPASBGR       7204.0   5156.463873
# ...         ...                 ...       ...          ...           ...
# 24940214  439.0 2023-01-28 05:29:00  SBRFSBFL      12184.0  12627.650660
# 24940215  438.0 2023-01-28 05:20:05  SBRFSBFL      12184.0  12627.650660
# 24940216  449.0 2023-01-28 04:25:02  SBRFSBFL      12184.0  12627.650660
# 24940217  449.0 2023-01-28 04:22:05  SBRFSBFL      12184.0  12627.650660
# 24940218  438.0 2023-01-28 05:20:01  SBRFSBFL      12184.0  12627.650660
#
#                  std   z_score
# 0         821.454519  2.492574
# 1         821.454519  2.492574
# 2         821.454519  2.492574
# 3         821.454519  2.492574
# 4         821.454519  2.492574
# ...              ...       ...
# 24940214  459.932470  0.964600
# 24940215  459.932470  0.964600
# 24940216  459.932470  0.964600
# 24940217  459.932470  0.964600
# 24940218  459.932470  0.964600
#
# [33532507 rows x 11 columns]

# %%
# Find the flightid with the minimum z-score (closest to the mean) for each linha
result = df.loc[df.groupby('linha')['z_score'].idxmin()][['linha', 'flightid']]

# %%
result.to_csv("data/normal_routes.csv", index=False)

# %%
import pandas as pd
normal_routes = pd.read_csv("data/normal_routes.csv")

# %%
normal_routes
# Out:
#         linha                          flightid
# 0    SBBRSBCF  087f686898ed53bd7ce99789c88867ff
# 1    SBBRSBCT  4066ac92918396c547eba2cbb3f96fcc
# 2    SBBRSBFL  e056f6a093d60ddd7387b0f0c50ec935
# 3    SBBRSBGL  f4d57ea06b69b8581d57e326dd4b60f4
# 4    SBBRSBGR  e53ce76973c98128df7010c67c0baf83
# ..        ...                               ...
# 131  SBSVSBKP  134b94aafe1e5a7f79548047d67fe76e
# 132  SBSVSBPA  e57783433a9423149190712f0790ef05
# 133  SBSVSBRF  88663ae48c0f2e45506c5d1d404f9d52
# 134  SBSVSBRJ  ff0786ad2a2fca47ecedc46db8ed99a8
# 135  SBSVSBSP  321b59e1d00fd4f710c56f50e128bbb7
#
# [136 rows x 2 columns]

# %%
cat62[cat62["flightid"] == "6c16f30d2d3b799e65874d15838a552c"]
# Out:
#                                flightid        lat        lon  flightlevel  \
# 10437  6c16f30d2d3b799e65874d15838a552c -17.683022 -42.254237        350.0
# 10438  6c16f30d2d3b799e65874d15838a552c -17.596812 -42.184386        350.0
# 10439  6c16f30d2d3b799e65874d15838a552c -17.575394 -42.166778        350.0
# 10440  6c16f30d2d3b799e65874d15838a552c -17.475093 -42.085838        350.0
# 10441  6c16f30d2d3b799e65874d15838a552c -21.378438 -45.169273        350.0
# ...                                 ...        ...        ...          ...
# 10676  6c16f30d2d3b799e65874d15838a552c -18.009586 -42.515419        350.0
# 10677  6c16f30d2d3b799e65874d15838a552c -17.908523 -42.434053        350.0
# 10678  6c16f30d2d3b799e65874d15838a552c -17.900976 -42.428155        350.0
# 10679  6c16f30d2d3b799e65874d15838a552c -17.799732 -42.346696        350.0
# 10680  6c16f30d2d3b799e65874d15838a552c -17.690945 -42.259773        350.0
#
#        speed            dt_radar     linha  flight_time
# 10437  497.0 2022-06-01 18:03:06  SBKPSBSV       6786.0
# 10438  497.0 2022-06-01 18:04:02  SBKPSBSV       6786.0
# 10439  497.0 2022-06-01 18:04:06  SBKPSBSV       6786.0
# 10440  496.0 2022-06-01 18:05:02  SBKPSBSV       6786.0
# 10441  512.0 2022-06-01 17:30:05  SBKPSBSV       6786.0
# ...      ...                 ...       ...          ...
# 10676  498.0 2022-06-01 18:00:06  SBKPSBSV       6786.0
# 10677  498.0 2022-06-01 18:01:02  SBKPSBSV       6786.0
# 10678  498.0 2022-06-01 18:01:06  SBKPSBSV       6786.0
# 10679  497.0 2022-06-01 18:02:02  SBKPSBSV       6786.0
# 10680  497.0 2022-06-01 18:03:02  SBKPSBSV       6786.0
#
# [179 rows x 8 columns]

# %%
# Ensure that 'flightid' is the index in the 'normal_routes' Dataframe 
normal_routes.set_index('flightid', inplace=True)

# Filter the 'cat62' DataFrame
filtered_cat62 = cat62[cat62['flightid'].isin(normal_routes.index)]

# %%
filtered_cat62
# Out:
#                                   flightid        lat        lon  flightlevel  \
# 10437     6c16f30d2d3b799e65874d15838a552c -17.683022 -42.254237        350.0
# 10438     6c16f30d2d3b799e65874d15838a552c -17.596812 -42.184386        350.0
# 10439     6c16f30d2d3b799e65874d15838a552c -17.575394 -42.166778        350.0
# 10440     6c16f30d2d3b799e65874d15838a552c -17.475093 -42.085838        350.0
# 10441     6c16f30d2d3b799e65874d15838a552c -21.378438 -45.169273        350.0
# ...                                    ...        ...        ...          ...
# 33684048  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.894645 -46.630156         94.0
# 33684049  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.761386 -46.562976         52.0
# 33684050  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.892669 -46.627372         94.0
# 33684051  0bceafe48dac0a05c58e4ecd8b5b96e9 -24.028492 -46.588753         76.0
# 33684052  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.698767 -46.605795         41.0
#
#           speed      dt_radar     linha
# 10437     497.0  1.654107e+12  SBKPSBSV
# 10438     497.0  1.654107e+12  SBKPSBSV
# 10439     497.0  1.654107e+12  SBKPSBSV
# 10440     496.0  1.654107e+12  SBKPSBSV
# 10441     512.0  1.654105e+12  SBKPSBSV
# ...         ...           ...       ...
# 33684048  201.0  1.681480e+12  SBGRSBSP
# 33684049  129.0  1.681481e+12  SBGRSBSP
# 33684050  202.0  1.681480e+12  SBGRSBSP
# 33684051  229.0  1.681480e+12  SBGRSBSP
# 33684052  125.0  1.681481e+12  SBGRSBSP
#
# [20305 rows x 7 columns]

# %%
filtered_cat62
# Out:
#                                   flightid        lat        lon  flightlevel  \
# 10437     6c16f30d2d3b799e65874d15838a552c -17.683022 -42.254237        350.0
# 10438     6c16f30d2d3b799e65874d15838a552c -17.596812 -42.184386        350.0
# 10439     6c16f30d2d3b799e65874d15838a552c -17.575394 -42.166778        350.0
# 10440     6c16f30d2d3b799e65874d15838a552c -17.475093 -42.085838        350.0
# 10441     6c16f30d2d3b799e65874d15838a552c -21.378438 -45.169273        350.0
# ...                                    ...        ...        ...          ...
# 33684048  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.894645 -46.630156         94.0
# 33684049  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.761386 -46.562976         52.0
# 33684050  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.892669 -46.627372         94.0
# 33684051  0bceafe48dac0a05c58e4ecd8b5b96e9 -24.028492 -46.588753         76.0
# 33684052  0bceafe48dac0a05c58e4ecd8b5b96e9 -23.698767 -46.605795         41.0
#
#           speed      dt_radar     linha
# 10437     497.0  1.654107e+12  SBKPSBSV
# 10438     497.0  1.654107e+12  SBKPSBSV
# 10439     497.0  1.654107e+12  SBKPSBSV
# 10440     496.0  1.654107e+12  SBKPSBSV
# 10441     512.0  1.654105e+12  SBKPSBSV
# ...         ...           ...       ...
# 33684048  201.0  1.681480e+12  SBGRSBSP
# 33684049  129.0  1.681481e+12  SBGRSBSP
# 33684050  202.0  1.681480e+12  SBGRSBSP
# 33684051  229.0  1.681480e+12  SBGRSBSP
# 33684052  125.0  1.681481e+12  SBGRSBSP
#
# [20305 rows x 7 columns]

# %%
import pandas as pd
test = pd.read_csv('data/idsc_dataset.csv', delimiter=';')
test = test[["flightid", "origem", "destino", "hora_ref", "path", "dt_dep"]]

# %%
test.to_csv("data/idsc_dataset_v2.csv", index=False)

# %%
test
# Out:
#                                flightid origem destino  hora_ref    dt_dep  \
# 0      4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00  11:53:30
# 1      865dbbbe74bebea18a71f24342516ff0   SBSP    SBCT  00:00:00  00:04:37
# 2      1803af9cfc6a2c74d188481e3ffd848e   SBGR    SBPA  01:00:00  01:33:15
# 3      f6af733a687f904183efd149ec713be5   SBCT    SBSV  03:00:00  03:54:14
# 4      6117f9ac60b7f66b740c9130be433313   SBRJ    SBGR  00:00:00  00:27:32
# ...                                 ...    ...     ...       ...       ...
# 40034  4e08052066073297c7a3c55798618324   SBSV    SBRF  20:00:00  20:25:00
# 40035  e22f120c65f5759aa8df576b59d71be3   SBCT    SBSP  08:00:00  08:50:22
# 40036  ca9399162037201a4d0c49c832a32739   SBGR    SBCF  11:00:00  11:30:03
# 40037  560136088f5f1493dbad809a3554172c   SBBR    SBGR  12:00:00  12:25:21
# 40038  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00  00:59:07
#
#                                           snapshot_radar  \
# 0      MULTIPOINT ((-0.9862962481402141 -0.2329259019...
# 1      MULTIPOINT ((-0.8863534722346053 -0.5093356150...
# 2      MULTIPOINT ((-0.8966138193125871 -0.5115119601...
# 3      MULTIPOINT ((-0.8586718860112791 -0.4418648049...
# 4      MULTIPOINT ((-0.8914635585346382 -0.5234904405...
# ...                                                  ...
# 40034  MULTIPOINT ((-0.8955415064673201 -0.5234137952...
# 40035  MULTIPOINT ((-0.8903194203987348 -0.5144905777...
# 40036  MULTIPOINT ((-0.8963144777278773 -0.5234059876...
# 40037                                                NaN
# 40038  MULTIPOINT ((-0.8995693853177327 -0.4320829335...
#
#                                                     path hora_esperas  \
# 0      http://satelite.cptec.inpe.br/repositoriogoes/...     10:00:00
# 1      http://satelite.cptec.inpe.br/repositoriogoes/...     23:00:00
# 2      http://satelite.cptec.inpe.br/repositoriogoes/...     00:00:00
# 3      http://satelite.cptec.inpe.br/repositoriogoes/...     02:00:00
# 4      http://satelite.cptec.inpe.br/repositoriogoes/...     23:00:00
# ...                                                  ...          ...
# 40034  http://satelite.cptec.inpe.br/repositoriogoes/...     19:00:00
# 40035  http://satelite.cptec.inpe.br/repositoriogoes/...     07:00:00
# 40036  http://satelite.cptec.inpe.br/repositoriogoes/...     10:00:00
# 40037  http://satelite.cptec.inpe.br/repositoriogoes/...     11:00:00
# 40038  http://satelite.cptec.inpe.br/repositoriogoes/...     23:00:00
#
#        esperas aero_esperas  ...  \
# 0            1         SBSP  ...
# 1            0         SBCT  ...
# 2            0         SBPA  ...
# 3            0         SBSV  ...
# 4            0         SBGR  ...
# ...        ...          ...  ...
# 40034        0         SBRF  ...
# 40035        0         SBSP  ...
# 40036        0         SBCF  ...
# 40037        0         SBGR  ...
# 40038        0         SBPA  ...
#
#                                                    metaf aero_metaf  \
# 0      METAF SBSP 211100Z  32007KT 9999       SCT033 ...       SBSP
# 1      METAF SBCT 150000Z  11008KT 1000     BR OVC033...       SBCT
# 2      METAF SBPA 030100Z 08005KT 9999       SCT011  ...       SBPA
# 3                                                    NaN        NaN
# 4       METAF SBGR 230000Z  32008KT CAVOK 24/04 Q1010=\n       SBGR
# ...                                                  ...        ...
# 40034                                                NaN        NaN
# 40035   METAF SBSP 090800Z  36003KT CAVOK 19/10 Q1017=\n       SBSP
# 40036   METAF SBCF 221100Z  13004KT CAVOK 21/09 Q1016=\n       SBCF
# 40037   METAF SBGR 231200Z  34010KT CAVOK 25/07 Q1012=\n       SBGR
# 40038  METAF SBPA 050000Z  20006KT 2000     BR OVC033...       SBPA
#
#       hora_metar                                              metar  \
# 0       10:00:00  METAR SBSP 211000Z 34007KT 290V010 CAVOK 18/13...
# 1       23:00:00  METAR SBCT 142300Z 13005KT 100V200 CAVOK 11/06...
# 2       00:00:00  METAR SBPA 030000Z 07004KT 030V090 9000 NSC 21...
# 3       02:00:00  METAR SBSV 150200Z 06009KT 9999 SCT020 25/22 Q...
# 4       23:00:00  METAR COR SBGR 222300Z 06004KT CAVOK 23/08 Q1013=
# ...          ...                                                ...
# 40034   19:00:00  METAR SBRF 181900Z 19015KT 9999 SCT023 BKN060 ...
# 40035   07:00:00  METAR SBSP 090700Z AUTO VRB02KT CAVOK 19/17 Q1...
# 40036   10:00:00   METAR SBCF 221000Z 16003KT 9000 NSC 13/12 Q1018=
# 40037   11:00:00      METAR SBGR 231100Z 03004KT CAVOK 25/10 Q1014=
# 40038   23:00:00  METAR SBPA 042300Z VRB02KT 8000 OVC009 17/16 Q...
#
#       aero_metar  hora_tcp troca  aero_tcp  hora_tcr aero_tcr
# 0           SBSP  11:00:00   0.0      SBSP       NaN      NaN
# 1           SBCT  00:00:00   0.0      SBCT  23:00:00     SBCT
# 2           SBPA  01:00:00   0.0      SBPA       NaN      NaN
# 3           SBSV  03:00:00   0.0      SBSV  02:00:00     SBSV
# 4           SBGR  00:00:00   0.0      SBGR  23:00:00     SBGR
# ...          ...       ...   ...       ...       ...      ...
# 40034       SBRF  20:00:00   0.0      SBRF       NaN      NaN
# 40035       SBSP  08:00:00   0.0      SBSP       NaN      NaN
# 40036       SBCF  11:00:00   0.0      SBCF       NaN      NaN
# 40037       SBGR  12:00:00   0.0      SBGR       NaN      NaN
# 40038       SBPA  00:00:00   0.0      SBPA       NaN      NaN
#
# [40039 rows x 21 columns]

# %%
test["linha"] = test["origem"] + test["destino"]

# %%
test.shape
# Out:
# (40039, 22)

# %%
del filtered_cat62["flightid"]

# %%
filtered_cat62
# Out:
#                 lat        lon  flightlevel  speed      dt_radar
# 10437    -17.683022 -42.254237        350.0  497.0  1.654107e+12
# 10438    -17.596812 -42.184386        350.0  497.0  1.654107e+12
# 10439    -17.575394 -42.166778        350.0  497.0  1.654107e+12
# 10440    -17.475093 -42.085838        350.0  496.0  1.654107e+12
# 10441    -21.378438 -45.169273        350.0  512.0  1.654105e+12
# ...             ...        ...          ...    ...           ...
# 33684048 -23.894645 -46.630156         94.0  201.0  1.681480e+12
# 33684049 -23.761386 -46.562976         52.0  129.0  1.681481e+12
# 33684050 -23.892669 -46.627372         94.0  202.0  1.681480e+12
# 33684051 -24.028492 -46.588753         76.0  229.0  1.681480e+12
# 33684052 -23.698767 -46.605795         41.0  125.0  1.681481e+12
#
# [20305 rows x 5 columns]

# %%
test = test.merge(filtered_cat62, on="linha", how="left")

# %%
test.to_csv("data/test_cat62.csv", index=False) #finaliza aq

# %%
for col in test.columns:
    print(col)
# Out:
# flightid
# origem
# destino
# hora_ref
# dt_dep
# snapshot_radar
# path
# hora_esperas
# esperas
# aero_esperas
# hora_metaf
# metaf
# aero_metaf
# hora_metar
# metar
# aero_metar
# hora_tcp
# troca
# aero_tcp
# hora_tcr
# aero_tcr
# linha
# lat
# lon
# flightlevel
# speed
# dt_radar
# flight_time

# %%
import pandas as pd
test = pd.read_csv('data/test_cat62.csv')

# %%
test["dt_radar"] = pd.to_datetime(test["dt_radar"], unit='ms')
test
# Out:
#                                  flightid origem destino  hora_ref  \
# 0        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 1        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 2        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 3        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 4        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# ...                                   ...    ...     ...       ...
# 5052222  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052223  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052224  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052225  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052226  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
#
#                                                       path    dt_dep  \
# 0        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 1        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 2        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 3        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 4        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# ...                                                    ...       ...
# 5052222  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052223  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052224  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052225  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052226  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
#
#             linha        lat        lon  flightlevel  speed  \
# 0        SBBRSBSP -21.566934 -46.786967        390.0  493.0
# 1        SBBRSBSP -20.214075 -46.985819        390.0  487.0
# 2        SBBRSBSP -23.491932 -47.056154         83.0  237.0
# 3        SBBRSBSP -23.361904 -47.081812         97.0  240.0
# 4        SBBRSBSP -18.248203 -47.295240        390.0  482.0
# ...           ...        ...        ...          ...    ...
# 5052222  SBGRSBPA -29.144617 -50.702264        191.0  360.0
# 5052223  SBGRSBPA -29.995381 -51.014212         22.0  175.0
# 5052224  SBGRSBPA -28.053176 -49.871894        360.0  441.0
# 5052225  SBGRSBPA -30.153200 -50.878138         47.0  186.0
# 5052226  SBGRSBPA -29.149470 -50.700959        190.0  345.0
#
#                    dt_radar                 data
# 0       2022-09-06 12:05:03  2023-08-21 11:00:00
# 1       2022-09-06 11:55:00  2023-08-21 11:00:00
# 2       2022-09-06 12:28:00  2023-08-21 11:00:00
# 3       2022-09-06 12:26:00  2023-08-21 11:00:00
# 4       2022-09-06 11:40:04  2023-08-21 11:00:00
# ...                     ...                  ...
# 5052222 2022-06-15 19:03:02  2023-09-05 00:00:00
# 5052223 2022-06-15 19:23:05  2023-09-05 00:00:00
# 5052224 2022-06-15 18:51:06  2023-09-05 00:00:00
# 5052225 2022-06-15 19:19:01  2023-09-05 00:00:00
# 5052226 2022-06-15 19:03:06  2023-09-05 00:00:00
#
# [5052227 rows x 13 columns]

# %%
aux = test.groupby("flightid")["data"].first()

# %%
aux = pd.DataFrame(aux).reset_index()
aux
# Out:
#                                flightid                data
# 0      00054c16230f8fb7cf565233af432bb8 2023-09-02 19:00:00
# 1      0005c08c2b064c695fac495d7a6b86b5 2023-08-17 08:00:00
# 2      00062261eae0cd9c9d44aba8d0e41617 2023-09-07 11:00:00
# 3      000625db56237c20414beebf94aab0d3 2023-08-15 22:00:00
# 4      0007f2ee7329b979f8d4187c5ea9670b 2023-09-13 00:00:00
# ...                                 ...                 ...
# 40034  fffac2757793e7abe724a23a4edb3371 2023-08-15 22:00:00
# 40035  fffc60c41625dd5fa17fc34d09b9b1d9 2023-09-10 13:00:00
# 40036  ffff94d470e6aa3bf4ae1f3649fdf1f0 2023-09-15 22:00:00
# 40037  ffff96ee92bf9da75c93a22669ff4811 2023-09-11 14:00:00
# 40038  ffffa7751e3a4ac054c0485b600bf630                 NaT
#
# [40039 rows x 2 columns]

# %%
aux["fdata"] = aux["data"]
del aux["data"]

# %%
test = test.merge(aux, on="flightid", how="left")

# %%
test["diff_date"] = test["fdata"] - test["dt_radar"]

# %%
test["dt_radar"] = test["dt_radar"] + test["diff_date"]

# %%
test
# Out:
#                                  flightid origem destino  hora_ref  \
# 0        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 1        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 2        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 3        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# 4        4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00
# ...                                   ...    ...     ...       ...
# 5052222  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052223  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052224  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052225  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
# 5052226  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00
#
#                                                       path    dt_dep  \
# 0        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 1        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 2        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 3        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# 4        http://satelite.cptec.inpe.br/repositoriogoes/...  11:53:30
# ...                                                    ...       ...
# 5052222  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052223  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052224  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052225  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
# 5052226  http://satelite.cptec.inpe.br/repositoriogoes/...  00:59:07
#
#             linha        lat        lon  flightlevel  speed  \
# 0        SBBRSBSP -21.566934 -46.786967        390.0  493.0
# 1        SBBRSBSP -20.214075 -46.985819        390.0  487.0
# 2        SBBRSBSP -23.491932 -47.056154         83.0  237.0
# 3        SBBRSBSP -23.361904 -47.081812         97.0  240.0
# 4        SBBRSBSP -18.248203 -47.295240        390.0  482.0
# ...           ...        ...        ...          ...    ...
# 5052222  SBGRSBPA -29.144617 -50.702264        191.0  360.0
# 5052223  SBGRSBPA -29.995381 -51.014212         22.0  175.0
# 5052224  SBGRSBPA -28.053176 -49.871894        360.0  441.0
# 5052225  SBGRSBPA -30.153200 -50.878138         47.0  186.0
# 5052226  SBGRSBPA -29.149470 -50.700959        190.0  345.0
#
#                    dt_radar                data         diff_date  \
# 0       2023-08-21 11:00:00 2023-08-21 11:00:00 348 days 22:54:57
# 1       2023-08-21 11:00:00 2023-08-21 11:00:00 348 days 23:05:00
# 2       2023-08-21 11:00:00 2023-08-21 11:00:00 348 days 22:32:00
# 3       2023-08-21 11:00:00 2023-08-21 11:00:00 348 days 22:34:00
# 4       2023-08-21 11:00:00 2023-08-21 11:00:00 348 days 23:19:56
# ...                     ...                 ...               ...
# 5052222 2023-09-05 00:00:00 2023-09-05 00:00:00 446 days 04:56:58
# 5052223 2023-09-05 00:00:00 2023-09-05 00:00:00 446 days 04:36:55
# 5052224 2023-09-05 00:00:00 2023-09-05 00:00:00 446 days 05:08:54
# 5052225 2023-09-05 00:00:00 2023-09-05 00:00:00 446 days 04:40:59
# 5052226 2023-09-05 00:00:00 2023-09-05 00:00:00 446 days 04:56:54
#
#                       fdata
# 0       2023-08-21 11:00:00
# 1       2023-08-21 11:00:00
# 2       2023-08-21 11:00:00
# 3       2023-08-21 11:00:00
# 4       2023-08-21 11:00:00
# ...                     ...
# 5052222 2023-09-05 00:00:00
# 5052223 2023-09-05 00:00:00
# 5052224 2023-09-05 00:00:00
# 5052225 2023-09-05 00:00:00
# 5052226 2023-09-05 00:00:00
#
# [5052227 rows x 15 columns]

# %%
test["data"] = pd.to_datetime(test["data"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /mnt/69fc90a9-6bd6-44ab-8de7-2ca55ea0520a/latamChalenge/genAuxTables.ipynb Cell 32 line 2
#       <a href='vscode-notebook-cell:/mnt/69fc90a9-6bd6-44ab-8de7-2ca55ea0520a/latamChalenge/genAuxTables.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> test["data"] = pd.to_datetime(test["data"])
# ----> <a href='vscode-notebook-cell:/mnt/69fc90a9-6bd6-44ab-8de7-2ca55ea0520a/latamChalenge/genAuxTables.ipynb#Y104sZmlsZQ%3D%3D?line=1'>2</a> test["sum_date"] = test["data"] + test["dt_radar"]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:5820, in Series._arith_method(self, other, op)
#    5818 def _arith_method(self, other, op):
#    5819     self, other = self._align_for_op(other)
# -> 5820     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:275, in arithmetic_op(left, right, op)
#     262 # NB: We assume that extract_array and ensure_wrapped_if_datetimelike
#     263 #  have already been called on `left` and `right`,
#     264 #  and `maybe_prepare_scalar_for_op` has already been called on `right`
#     265 # We need to special-case datetime64/timedelta64 dtypes (e.g. because numpy
#     266 # casts integer dtypes to timedelta64 when operating with timedelta64 - GH#22390)
#     268 if (
#     269     should_extension_dispatch(left, right)
#     270     or isinstance(right, (Timedelta, BaseOffset, Timestamp))
#    (...)
#     273     # Timedelta/Timestamp and other custom scalars are included in the check
#     274     # because numexpr will fail on it, see GH#31457
# --> 275     res_values = op(left, right)
#     276 else:
#     277     # TODO we should handle EAs consistently and move this check before the if/else
#     278     # (https://github.com/pandas-dev/pandas/issues/41165)
#     279     # error: Argument 2 to "_bool_arith_check" has incompatible type
#     280     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:1359, in DatetimeLikeArrayMixin.__add__(self, other)
#    1354     result = self._addsub_object_array(other, operator.add)
#    1355 elif lib.is_np_dtype(other_dtype, "M") or isinstance(
#    1356     other_dtype, DatetimeTZDtype
#    1357 ):
#    1358     # DatetimeIndex, ndarray[datetime64]
# -> 1359     return self._add_datetime_arraylike(other)
#    1360 elif is_integer_dtype(other_dtype):
#    1361     if not isinstance(self.dtype, PeriodDtype):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py:1074, in DatetimeLikeArrayMixin._add_datetime_arraylike(self, other)
#    1071 @final
#    1072 def _add_datetime_arraylike(self, other: DatetimeArray) -> DatetimeArray:
#    1073     if not lib.is_np_dtype(self.dtype, "m"):
# -> 1074         raise TypeError(
#    1075             f"cannot add {type(self).__name__} and {type(other).__name__}"
#    1076         )
#    1078     # defer to DatetimeArray.__add__
#    1079     return other + self
#
# TypeError: cannot add DatetimeArray and DatetimeArray

# %%
test["diff_date"] = test["data"] - test["dt_radar"]

# %%
test["diff_date"]
# Out:
# 0         348 days 22:54:57
# 1         348 days 23:05:00
# 2         348 days 22:32:00
# 3         348 days 22:34:00
# 4         348 days 23:19:56
#                  ...
# 5052222   446 days 04:56:58
# 5052223   446 days 04:36:55
# 5052224   446 days 05:08:54
# 5052225   446 days 04:40:59
# 5052226   446 days 04:56:54
# Name: diff_date, Length: 5052227, dtype: timedelta64[ns]

# %%
storm = pd.read_csv('data/test_storm_areas')

# %%
storm["data"] = pd.to_datetime(storm["data"])

# %%
storm[storm["data"] > pd.to_datetime("20230821")]
# Out:
#                                         polygon   centroid_x   centroid_y  \
# 52284     ('S11635384_202308210100.jpg.jpg', 0)  1444.999463  1072.980167
# 52285     ('S11635384_202308210100.jpg.jpg', 1)  1221.104660  1844.708510
# 52286     ('S11635384_202308210100.jpg.jpg', 2)  1687.701603  2081.989203
# 52287     ('S11635384_202308210100.jpg.jpg', 3)  1856.314547  1549.202689
# 52288     ('S11635384_202308210100.jpg.jpg', 4)  1467.161257   808.233680
# ...                                         ...          ...          ...
# 409030  ('S11635384_202309250000.jpg.jpg', 464)   941.500000   974.000000
# 409031  ('S11635384_202309250000.jpg.jpg', 465)  1761.500000   741.000000
# 409032  ('S11635384_202309250000.jpg.jpg', 466)  1889.000000  2190.000000
# 409033  ('S11635384_202309250000.jpg.jpg', 467)  1325.000000  2190.000000
# 409034  ('S11635384_202309250000.jpg.jpg', 468)   941.000000   754.000000
#
#         area_estimate  poly                data        lat        lon
# 52284        344353.5     0 2023-08-21 01:00:00 -55.684564  -5.724837
# 52285        242367.5     1 2023-08-21 01:00:00 -64.930351 -37.534075
# 52286        125162.0     2 2023-08-21 01:00:00 -45.662123 -47.314353
# 52287         89408.0     3 2023-08-21 01:00:00 -38.699213 -25.353862
# 52288         29208.0     4 2023-08-21 01:00:00 -54.769388   5.187532
# ...               ...   ...                 ...        ...        ...
# 409030           12.0   464 2023-09-25 00:00:00 -76.476690  -1.645054
# 409031           10.0   465 2023-09-25 00:00:00 -42.614602   7.958782
# 409032            8.0   466 2023-09-25 00:00:00 -37.349460 -51.766362
# 409033            8.0   467 2023-09-25 00:00:00 -60.639969 -51.766362
# 409034            8.0   468 2023-09-25 00:00:00 -76.497338   7.422945
#
# [356751 rows x 8 columns]

# %%
test["data"] = pd.to_datetime(test["path"].str.split("/").str[-1].str.split("_", expand=True)[1].str.split(".", expand=True)[0])

# %%
test.to_csv("data/test_cat62.csv", index=False)

# %%
test["dt_radar"] = pd.to_datetime(test["dt_radar"], unit="ms")

# %%
test["dt_dep"] = pd.to_datetime(test["dt_dep"])
# Out:
# /tmp/ipykernel_416269/2456941913.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test["dt_dep"] = pd.to_datetime(test["dt_dep"])

# %%
test = test.sort_values(by=['flightid', 'dt_radar'])

# Obter a primeira ocorrência de route_event por flightid e calcular a diferença com flight_start
first_route_event = test.groupby('flightid')[['flightid','dt_radar']].transform('first')

# %%
test = test.merge(first_route_event, on="flightid", how="left")

# %%
aux = test.groupby('flightid')['dt_radar'].transform('first')
# Out:
#                                flightid origem destino              dt_dep  \
# 0      7945735584a3297121c4f5ae0de8ecd1   SBKP    SBSV 2023-05-30 11:36:03
# 1      7945735584a3297121c4f5ae0de8ecd1   SBKP    SBSV 2023-05-30 11:36:03
# 2      7945735584a3297121c4f5ae0de8ecd1   SBKP    SBSV 2023-05-30 11:36:03
# 3      7945735584a3297121c4f5ae0de8ecd1   SBKP    SBSV 2023-05-30 11:36:03
# 4      7945735584a3297121c4f5ae0de8ecd1   SBKP    SBSV 2023-05-30 11:36:03
# ...                                 ...    ...     ...                 ...
# 12668  c3c8b46a8d4c0a09565b1c61a475d2d9   SBSP    SBCT 2023-05-20 13:35:06
# 12669  c3c8b46a8d4c0a09565b1c61a475d2d9   SBSP    SBCT 2023-05-20 13:35:06
# 12670  c3c8b46a8d4c0a09565b1c61a475d2d9   SBSP    SBCT 2023-05-20 13:35:06
# 12671  c3c8b46a8d4c0a09565b1c61a475d2d9   SBSP    SBCT 2023-05-20 13:35:06
# 12672  c3c8b46a8d4c0a09565b1c61a475d2d9   SBSP    SBCT 2023-05-20 13:35:06
#
#                       hora_ref  \
# 0      2023-05-30 11:00:00.000
# 1      2023-05-30 11:00:00.000
# 2      2023-05-30 11:00:00.000
# 3      2023-05-30 11:00:00.000
# 4      2023-05-30 11:00:00.000
# ...                        ...
# 12668  2023-05-20 13:00:00.000
# 12669  2023-05-20 13:00:00.000
# 12670  2023-05-20 13:00:00.000
# 12671  2023-05-20 13:00:00.000
# 12672  2023-05-20 13:00:00.000
#
#                                           snapshot_radar  \
# 0      MULTIPOINT ((-0.8807200448127578 -0.5148453155...
# 1      MULTIPOINT ((-0.8807200448127578 -0.5148453155...
# 2      MULTIPOINT ((-0.8807200448127578 -0.5148453155...
# 3      MULTIPOINT ((-0.8807200448127578 -0.5148453155...
# 4      MULTIPOINT ((-0.8807200448127578 -0.5148453155...
# ...                                                  ...
# 12668  MULTIPOINT ((-0.8911832312799806 -0.5097777857...
# 12669  MULTIPOINT ((-0.8911832312799806 -0.5097777857...
# 12670  MULTIPOINT ((-0.8911832312799806 -0.5097777857...
# 12671  MULTIPOINT ((-0.8911832312799806 -0.5097777857...
# 12672  MULTIPOINT ((-0.8911832312799806 -0.5097777857...
#
#                                                     path  \
# 0      http://satelite.cptec.inpe.br/repositoriogoes/...
# 1      http://satelite.cptec.inpe.br/repositoriogoes/...
# 2      http://satelite.cptec.inpe.br/repositoriogoes/...
# 3      http://satelite.cptec.inpe.br/repositoriogoes/...
# 4      http://satelite.cptec.inpe.br/repositoriogoes/...
# ...                                                  ...
# 12668  http://satelite.cptec.inpe.br/repositoriogoes/...
# 12669  http://satelite.cptec.inpe.br/repositoriogoes/...
# 12670  http://satelite.cptec.inpe.br/repositoriogoes/...
# 12671  http://satelite.cptec.inpe.br/repositoriogoes/...
# 12672  http://satelite.cptec.inpe.br/repositoriogoes/...
#
#                   hora_esperas  esperas aero_esperas  ...  \
# 0      2023-05-30 10:00:00.000        0         SBSV  ...
# 1      2023-05-30 10:00:00.000        0         SBSV  ...
# 2      2023-05-30 10:00:00.000        0         SBSV  ...
# 3      2023-05-30 10:00:00.000        0         SBSV  ...
# 4      2023-05-30 10:00:00.000        0         SBSV  ...
# ...                        ...      ...          ...  ...
# 12668  2023-05-20 12:00:00.000        0         SBCT  ...
# 12669  2023-05-20 12:00:00.000        0         SBCT  ...
# 12670  2023-05-20 12:00:00.000        0         SBCT  ...
# 12671  2023-05-20 12:00:00.000        0         SBCT  ...
# 12672  2023-05-20 12:00:00.000        0         SBCT  ...
#
#                       hora_tcr aero_tcr     linha        lat        lon  \
# 0                          NaN      NaN  SBKPSBSV -17.683022 -42.254237
# 1                          NaN      NaN  SBKPSBSV -17.596812 -42.184386
# 2                          NaN      NaN  SBKPSBSV -17.575394 -42.166778
# 3                          NaN      NaN  SBKPSBSV -17.475093 -42.085838
# 4                          NaN      NaN  SBKPSBSV -21.378438 -45.169273
# ...                        ...      ...       ...        ...        ...
# 12668  2023-05-20 13:00:00.000     SBCT  SBSPSBCT -23.871106 -47.092488
# 12669  2023-05-20 13:00:00.000     SBCT  SBSPSBCT -25.565582 -48.929200
# 12670  2023-05-20 13:00:00.000     SBCT  SBSPSBCT -25.603973 -49.090110
# 12671  2023-05-20 13:00:00.000     SBCT  SBSPSBCT -25.414480 -48.597751
# 12672  2023-05-20 13:00:00.000     SBCT  SBSPSBCT -23.581591 -46.721669
#
#       flightlevel  speed            dt_radar time_difference  \
# 0           350.0  497.0 2022-06-01 18:03:06               7
# 1           350.0  497.0 2022-06-01 18:04:02               7
# 2           350.0  497.0 2022-06-01 18:04:06               7
# 3           350.0  496.0 2022-06-01 18:05:02               7
# 4           350.0  512.0 2022-06-01 17:30:05               6
# ...           ...    ...                 ...             ...
# 12668       171.0  336.0 2022-06-10 10:37:05              -3
# 12669        79.0  232.0 2022-06-10 11:03:01              -2
# 12670        48.0  144.0 2022-06-10 11:07:06              -2
# 12671       143.0  295.0 2022-06-10 10:58:05              -3
# 12672        57.0  211.0 2022-06-10 10:31:04              -3
#
#               route_event
# 0     2023-05-30 11:43:03
# 1     2023-05-30 11:43:03
# 2     2023-05-30 11:43:03
# 3     2023-05-30 11:43:03
# 4     2023-05-30 11:42:03
# ...                   ...
# 12668 2023-05-20 13:32:06
# 12669 2023-05-20 13:33:06
# 12670 2023-05-20 13:33:06
# 12671 2023-05-20 13:32:06
# 12672 2023-05-20 13:32:06
#
# [12673 rows x 29 columns]

# %%
test[["flightid", "linha", "lat", "lon", "flightlevel", "speed", "dt_dep", "dt_radar"]].to_csv("data/test_cat62.csv", index=False)

# %%
import pandas as pd
test = pd.read_csv("data/idsc_dataset.csv", sep=";")

# %%
#filtered_cat62.to_csv("data/test_cat62.csv", index=False)

# %%
test
# Out:
#                                flightid origem destino  hora_ref    dt_dep  \
# 0      4f0356600f61e3fcbea8ed8a137a2423   SBBR    SBSP  11:00:00  11:53:30
# 1      865dbbbe74bebea18a71f24342516ff0   SBSP    SBCT  00:00:00  00:04:37
# 2      1803af9cfc6a2c74d188481e3ffd848e   SBGR    SBPA  01:00:00  01:33:15
# 3      f6af733a687f904183efd149ec713be5   SBCT    SBSV  03:00:00  03:54:14
# 4      6117f9ac60b7f66b740c9130be433313   SBRJ    SBGR  00:00:00  00:27:32
# ...                                 ...    ...     ...       ...       ...
# 40034  4e08052066073297c7a3c55798618324   SBSV    SBRF  20:00:00  20:25:00
# 40035  e22f120c65f5759aa8df576b59d71be3   SBCT    SBSP  08:00:00  08:50:22
# 40036  ca9399162037201a4d0c49c832a32739   SBGR    SBCF  11:00:00  11:30:03
# 40037  560136088f5f1493dbad809a3554172c   SBBR    SBGR  12:00:00  12:25:21
# 40038  007ff2faa56e24e8422a07f1fe1d116a   SBGR    SBPA  00:00:00  00:59:07
#
#                                           snapshot_radar  \
# 0      MULTIPOINT ((-0.9862962481402141 -0.2329259019...
# 1      MULTIPOINT ((-0.8863534722346053 -0.5093356150...
# 2      MULTIPOINT ((-0.8966138193125871 -0.5115119601...
# 3      MULTIPOINT ((-0.8586718860112791 -0.4418648049...
# 4      MULTIPOINT ((-0.8914635585346382 -0.5234904405...
# ...                                                  ...
# 40034  MULTIPOINT ((-0.8955415064673201 -0.5234137952...
# 40035  MULTIPOINT ((-0.8903194203987348 -0.5144905777...
# 40036  MULTIPOINT ((-0.8963144777278773 -0.5234059876...
# 40037                                                NaN
# 40038  MULTIPOINT ((-0.8995693853177327 -0.4320829335...
#
#                                                     path hora_esperas  \
# 0      http://satelite.cptec.inpe.br/repositoriogoes/...     10:00:00
# 1      http://satelite.cptec.inpe.br/repositoriogoes/...     23:00:00
# 2      http://satelite.cptec.inpe.br/repositoriogoes/...     00:00:00
# 3      http://satelite.cptec.inpe.br/repositoriogoes/...     02:00:00
# 4      http://satelite.cptec.inpe.br/repositoriogoes/...     23:00:00
# ...                                                  ...          ...
# 40034  http://satelite.cptec.inpe.br/repositoriogoes/...     19:00:00
# 40035  http://satelite.cptec.inpe.br/repositoriogoes/...     07:00:00
# 40036  http://satelite.cptec.inpe.br/repositoriogoes/...     10:00:00
# 40037  http://satelite.cptec.inpe.br/repositoriogoes/...     11:00:00
# 40038  http://satelite.cptec.inpe.br/repositoriogoes/...     23:00:00
#
#        esperas aero_esperas  ...  \
# 0            1         SBSP  ...
# 1            0         SBCT  ...
# 2            0         SBPA  ...
# 3            0         SBSV  ...
# 4            0         SBGR  ...
# ...        ...          ...  ...
# 40034        0         SBRF  ...
# 40035        0         SBSP  ...
# 40036        0         SBCF  ...
# 40037        0         SBGR  ...
# 40038        0         SBPA  ...
#
#                                                    metaf aero_metaf  \
# 0      METAF SBSP 211100Z  32007KT 9999       SCT033 ...       SBSP
# 1      METAF SBCT 150000Z  11008KT 1000     BR OVC033...       SBCT
# 2      METAF SBPA 030100Z 08005KT 9999       SCT011  ...       SBPA
# 3                                                    NaN        NaN
# 4       METAF SBGR 230000Z  32008KT CAVOK 24/04 Q1010=\n       SBGR
# ...                                                  ...        ...
# 40034                                                NaN        NaN
# 40035   METAF SBSP 090800Z  36003KT CAVOK 19/10 Q1017=\n       SBSP
# 40036   METAF SBCF 221100Z  13004KT CAVOK 21/09 Q1016=\n       SBCF
# 40037   METAF SBGR 231200Z  34010KT CAVOK 25/07 Q1012=\n       SBGR
# 40038  METAF SBPA 050000Z  20006KT 2000     BR OVC033...       SBPA
#
#       hora_metar                                              metar  \
# 0       10:00:00  METAR SBSP 211000Z 34007KT 290V010 CAVOK 18/13...
# 1       23:00:00  METAR SBCT 142300Z 13005KT 100V200 CAVOK 11/06...
# 2       00:00:00  METAR SBPA 030000Z 07004KT 030V090 9000 NSC 21...
# 3       02:00:00  METAR SBSV 150200Z 06009KT 9999 SCT020 25/22 Q...
# 4       23:00:00  METAR COR SBGR 222300Z 06004KT CAVOK 23/08 Q1013=
# ...          ...                                                ...
# 40034   19:00:00  METAR SBRF 181900Z 19015KT 9999 SCT023 BKN060 ...
# 40035   07:00:00  METAR SBSP 090700Z AUTO VRB02KT CAVOK 19/17 Q1...
# 40036   10:00:00   METAR SBCF 221000Z 16003KT 9000 NSC 13/12 Q1018=
# 40037   11:00:00      METAR SBGR 231100Z 03004KT CAVOK 25/10 Q1014=
# 40038   23:00:00  METAR SBPA 042300Z VRB02KT 8000 OVC009 17/16 Q...
#
#       aero_metar  hora_tcp troca  aero_tcp  hora_tcr aero_tcr
# 0           SBSP  11:00:00   0.0      SBSP       NaN      NaN
# 1           SBCT  00:00:00   0.0      SBCT  23:00:00     SBCT
# 2           SBPA  01:00:00   0.0      SBPA       NaN      NaN
# 3           SBSV  03:00:00   0.0      SBSV  02:00:00     SBSV
# 4           SBGR  00:00:00   0.0      SBGR  23:00:00     SBGR
# ...          ...       ...   ...       ...       ...      ...
# 40034       SBRF  20:00:00   0.0      SBRF       NaN      NaN
# 40035       SBSP  08:00:00   0.0      SBSP       NaN      NaN
# 40036       SBCF  11:00:00   0.0      SBCF       NaN      NaN
# 40037       SBGR  12:00:00   0.0      SBGR       NaN      NaN
# 40038       SBPA  00:00:00   0.0      SBPA       NaN      NaN
#
# [40039 rows x 21 columns]

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, first, to_date, unix_timestamp
from pyspark.sql.window import Window

spark = SparkSession.builder.config("spark.driver.memory", "15g").appName("Dataframe Example").getOrCreate()

cat62 = spark.read.csv('data/cat62.csv', header=True)

bimtra = spark.read.csv('data/bimtra.csv', header=True)
bimtra = bimtra.withColumn("linha", bimtra["origem"] + bimtra["destino"])
bimtra = bimtra.groupBy("flightid").agg(first("linha").alias("linha"))
bimtra = bimtra.select("*")
bimtra = bimtra.drop("linha")
cat62 = cat62.join(bimtra, "flightid", "left_outer")

normal_routes = spark.read.csv('data/normal_routes.csv', header=True)
cat62_filtered = cat62.join(normal_routes, cat62.flightid == normal_routes.flightid, how='inner')

test = spark.createDataFrame(test[["flightid", "origem", "destino", "hora_ref", "path", "dt_dep"]])
# Out:
# /home/bruno/.local/lib/python3.10/site-packages/pyspark/sql/pandas/conversion.py:485: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   if should_localize and is_datetime64tz_dtype(s.dtype) and s.dt.tz is not None:

# %%
test.show()
# Out:
# 23/10/05 21:16:52 WARN TaskSetManager: Stage 43 contains a task of very large size (22557 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 43:>                                                         (0 + 1) / 1]
# +--------------------+------+-------+--------+--------+--------------------+--------------------+------------+-------+------------+----------+--------------------+----------+----------+--------------------+----------+--------+-----+--------+--------+--------+
# |            flightid|origem|destino|hora_ref|  dt_dep|      snapshot_radar|                path|hora_esperas|esperas|aero_esperas|hora_metaf|               metaf|aero_metaf|hora_metar|               metar|aero_metar|hora_tcp|troca|aero_tcp|hora_tcr|aero_tcr|
# +--------------------+------+-------+--------+--------+--------------------+--------------------+------------+-------+------------+----------+--------------------+----------+----------+--------------------+----------+--------+-----+--------+--------+--------+
# |4f0356600f61e3fcb...|  SBBR|   SBSP|11:00:00|11:53:30|MULTIPOINT ((-0.9...|http://satelite.c...|    10:00:00|      1|        SBSP|  11:00:00|METAF SBSP 211100...|      SBSP|  10:00:00|METAR SBSP 211000...|      SBSP|11:00:00|  0.0|    SBSP|     NaN|     NaN|
# |865dbbbe74bebea18...|  SBSP|   SBCT|00:00:00|00:04:37|MULTIPOINT ((-0.8...|http://satelite.c...|    23:00:00|      0|        SBCT|  00:00:00|METAF SBCT 150000...|      SBCT|  23:00:00|METAR SBCT 142300...|      SBCT|00:00:00|  0.0|    SBCT|23:00:00|    SBCT|
# |1803af9cfc6a2c74d...|  SBGR|   SBPA|01:00:00|01:33:15|MULTIPOINT ((-0.8...|http://satelite.c...|    00:00:00|      0|        SBPA|  01:00:00|METAF SBPA 030100...|      SBPA|  00:00:00|METAR SBPA 030000...|      SBPA|01:00:00|  0.0|    SBPA|     NaN|     NaN|
# |f6af733a687f90418...|  SBCT|   SBSV|03:00:00|03:54:14|MULTIPOINT ((-0.8...|http://satelite.c...|    02:00:00|      0|        SBSV|       NaN|                 NaN|       NaN|  02:00:00|METAR SBSV 150200...|      SBSV|03:00:00|  0.0|    SBSV|02:00:00|    SBSV|
# |6117f9ac60b7f66b7...|  SBRJ|   SBGR|00:00:00|00:27:32|MULTIPOINT ((-0.8...|http://satelite.c...|    23:00:00|      0|        SBGR|  00:00:00|METAF SBGR 230000...|      SBGR|  23:00:00|METAR COR SBGR 22...|      SBGR|00:00:00|  0.0|    SBGR|23:00:00|    SBGR|
# |f38e70bf6cbea10dd...|  SBCF|   SBSV|09:00:00|09:10:47|MULTIPOINT ((-0.8...|http://satelite.c...|    08:00:00|      0|        SBSV|       NaN|                 NaN|       NaN|  08:00:00|METAR SBSV 130800...|      SBSV|09:00:00|  0.0|    SBSV|     NaN|     NaN|
# |26d9687c376fc00f5...|  SBSP|   SBCF|09:00:00|09:25:42|MULTIPOINT ((-0.8...|http://satelite.c...|    08:00:00|      0|        SBCF|  09:00:00|METAF SBCF 210900...|      SBCF|  08:00:00|METAR SBCF 210800...|      SBCF|09:00:00|  0.0|    SBCF|08:00:00|    SBCF|
# |ca61361d356c68e22...|  SBSV|   SBSP|13:00:00|13:28:46|                 NaN|http://satelite.c...|    12:00:00|      0|        SBSP|  13:00:00|METAF SBSP 111300...|      SBSP|  12:00:00|METAR SBSP 111200...|      SBSP|13:00:00|  0.0|    SBSP|     NaN|     NaN|
# |72301f4a63689438a...|  SBPA|   SBBR|20:00:00|20:48:02|MULTIPOINT ((-0.8...|http://satelite.c...|    19:00:00|      0|        SBBR|  20:00:00|METAF SBBR 132000...|      SBBR|  19:00:00|METAR SBBR 131900...|      SBBR|20:00:00|  0.0|    SBBR|     NaN|     NaN|
# |532c4932b33905129...|  SBCF|   SBRF|22:00:00|22:16:40|MULTIPOINT ((-0.8...|http://satelite.c...|    21:00:00|      0|        SBRF|       NaN|                 NaN|       NaN|  21:00:00|METAR SBRF 012100...|      SBRF|22:00:00|  0.0|    SBRF|     NaN|     NaN|
# |789c7ee47309c46de...|  SBSP|   SBRJ|13:00:00|13:24:44|                 NaN|http://satelite.c...|    12:00:00|      0|        SBRJ|  13:00:00|METAF SBRJ 161300...|      SBRJ|  12:00:00|METAR SBRJ 161200...|      SBRJ|13:00:00|  0.0|    SBRJ|12:00:00|    SBRJ|
# |2537c20e7dfea4cb2...|  SBGL|   SBGR|23:00:00|23:25:41|MULTIPOINT ((-0.8...|http://satelite.c...|    22:00:00|      0|        SBGR|  23:00:00|METAF SBGR 302300...|      SBGR|  22:00:00|METAR SBGR 302200...|      SBGR|23:00:00|  0.0|    SBGR|     NaN|     NaN|
# |51a26098b61a768d5...|  SBRF|   SBSP|06:00:00|06:05:58|MULTIPOINT ((-0.6...|http://satelite.c...|    05:00:00|      0|        SBSP|  06:00:00|METAF SBSP 290600...|      SBSP|  05:00:00|METAR SBSP 290500...|      SBSP|06:00:00|  0.0|    SBSP|     NaN|     NaN|
# |d3a3c7c254dd51872...|  SBGL|   SBGR|22:00:00|22:00:15|MULTIPOINT ((-0.8...|http://satelite.c...|    21:00:00|      0|        SBGR|  22:00:00|METAF SBGR 292200...|      SBGR|  21:00:00|METAR SBGR 292100...|      SBGR|22:00:00|  0.0|    SBGR|     NaN|     NaN|
# |a3d5202525918cf2c...|  SBGR|   SBGL|23:00:00|23:38:09|MULTIPOINT ((-0.8...|http://satelite.c...|    22:00:00|      0|        SBGL|  23:00:00|METAF SBGL 222300...|      SBGL|  22:00:00|METAR SBGL 222200...|      SBGL|23:00:00|  0.0|    SBGL|     NaN|     NaN|
# |6b7ac0692df6929ef...|  SBCF|   SBSP|11:00:00|11:26:40|MULTIPOINT ((-0.8...|http://satelite.c...|    10:00:00|      0|        SBSP|  11:00:00|METAF SBSP 111100...|      SBSP|  10:00:00|METAR SBSP 111000...|      SBSP|11:00:00|  0.0|    SBSP|     NaN|     NaN|
# |04d94ea3e1ab99243...|  SBPA|   SBCT|19:00:00|19:06:06|MULTIPOINT ((-0.8...|http://satelite.c...|    18:00:00|      0|        SBCT|  19:00:00|METAF SBCT 151900...|      SBCT|  18:00:00|METAR SBCT 151800...|      SBCT|19:00:00|  0.0|    SBCT|18:00:00|    SBCT|
# |a11dc44b16fc66de9...|  SBPA|   SBSP|11:00:00|11:03:07|                 NaN|http://satelite.c...|    10:00:00|      0|        SBSP|  11:00:00|METAF SBSP 151100...|      SBSP|  10:00:00|METAR SBSP 151000...|      SBSP|11:00:00|  0.0|    SBSP|     NaN|     NaN|
# |b5916d50b537379f6...|  SBGR|   SBSV|17:00:00|17:14:14|MULTIPOINT ((-0.8...|http://satelite.c...|    16:00:00|      0|        SBSV|       NaN|                 NaN|       NaN|  16:00:00|METAR SBSV 201600...|      SBSV|17:00:00|  0.0|    SBSV|     NaN|     NaN|
# |ca75b5ec5e9afb403...|  SBCT|   SBRJ|20:00:00|20:33:45|MULTIPOINT ((-0.8...|http://satelite.c...|    19:00:00|      0|        SBRJ|  20:00:00|METAF SBRJ 312000...|      SBRJ|  19:00:00|METAR SBRJ 311900...|      SBRJ|20:00:00|  0.0|    SBRJ|19:00:00|    SBRJ|
# +--------------------+------+-------+--------+--------+--------------------+--------------------+------------+-------+------------+----------+--------------------+----------+----------+--------------------+----------+--------+-----+--------+--------+--------+
# only showing top 20 rows

# %%
test = test.withColumn("linha_test", test["origem"] + test["destino"])

cat62_filtered = cat62_filtered.drop("flightid")

test = test.join(cat62_filtered, test.linha_test == cat62_filtered.linha, "left")

# %%
test = test.drop('linha_test') 
test = test.withColumn("dt_radar", (col("dt_radar") / 1000).cast("timestamp"))
test = test.withColumn("dt_dep", to_date(unix_timestamp(col('dt_dep'), 'yyyy-MM-dd').cast("timestamp")))

test = test.orderBy("flightid", "dt_radar")

window = Window.partitionBy('flightid').orderBy('dt_radar')
first_route_event = test.select('flightid', first('dt_radar').over(window).alias('first_dt_radar'))

test = test.join(first_route_event, on='flightid', how="left")

#test.write.csv('data/test_cat62_v3.csv', header=True)
#
#test.show()

# %%
test = test.toPandas()
# Out:
# /home/bruno/.local/lib/python3.10/site-packages/pyspark/sql/pandas/types.py:563: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   if not is_datetime64tz_dtype(pser.dtype):
# /home/bruno/.local/lib/python3.10/site-packages/pyspark/sql/pandas/types.py:379: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   if is_datetime64tz_dtype(s.dtype):
# /home/bruno/.local/lib/python3.10/site-packages/pyspark/sql/pandas/types.py:563: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   if not is_datetime64tz_dtype(pser.dtype):
# /home/bruno/.local/lib/python3.10/site-packages/pyspark/sql/pandas/types.py:379: FutureWarning: is_datetime64tz_dtype is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.DatetimeTZDtype)` instead.
#   if is_datetime64tz_dtype(s.dtype):

# %%
test
# Out:
#                                flightid origem destino  hora_ref  \
# 0      9846ee0f2bf5e2d99ead82a4422d96f6   SBPA    SBSP  23:00:00
# 1      137e559b6e4007ef8678005c48467b86   SBRJ    SBBR  19:00:00
# 2      f426ad637ab4343dbb6a0d9ee9a7c84e   SBSP    SBRJ  14:00:00
# 3      062f1f01ea5e29b13d569523f7c6f5a5   SBGR    SBPA  12:00:00
# 4      bbb78ff7917953cff1bacac41261423e   SBBR    SBSP  08:00:00
# ...                                 ...    ...     ...       ...
# 40034  ee167565d8a718980a4778116b830c7b   SBSP    SBPA  18:00:00
# 40035  0958a5bb2d1eec5d2f1fa6f23641021c   SBCT    SBRJ  09:00:00
# 40036  f78acfb562cf86b315b1bc393af1a3d8   SBCF    SBRF  11:00:00
# 40037  a0549293808d06a2aad929dba47555be   SBCT    SBGR  09:00:00
# 40038  bd780478b4364864a58bdce5967cf5cf   SBBR    SBRJ  22:00:00
#
#                                                     path dt_dep   lat   lon  \
# 0      http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 1      http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 2      http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 3      http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 4      http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# ...                                                  ...    ...   ...   ...
# 40034  http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 40035  http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 40036  http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 40037  http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
# 40038  http://satelite.cptec.inpe.br/repositoriogoes/...   None  None  None
#
#       flightlevel speed dt_radar linha first_dt_radar
# 0            None  None      NaT  None            NaT
# 1            None  None      NaT  None            NaT
# 2            None  None      NaT  None            NaT
# 3            None  None      NaT  None            NaT
# 4            None  None      NaT  None            NaT
# ...           ...   ...      ...   ...            ...
# 40034        None  None      NaT  None            NaT
# 40035        None  None      NaT  None            NaT
# 40036        None  None      NaT  None            NaT
# 40037        None  None      NaT  None            NaT
# 40038        None  None      NaT  None            NaT
#
# [40039 rows x 13 columns]
